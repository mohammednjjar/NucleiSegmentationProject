# %%
# Import necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
# Explore the dataset structure
dataset_path = "/kaggle/input/bowl-2018"

# List all files and folders
for root, dirs, files in os.walk(dataset_path):
    print("Root:", root)
    print("Directories:", dirs)
    print("Files:", files[:5])  # Display first 5 files for brevity
    print("-" * 50)
# Out:
# Root: /kaggle/input/bowl-2018
# Directories: ['Bowl 2018']
# Files: []
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018
# Directories: ['validation folder', 'train folder', 'test folder']
# Files: []
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/validation folder
# Directories: ['labelcol', 'img']
# Files: []
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/validation folder/labelcol
# Directories: []
# Files: ['0050.png', '0006.png', '0003.png', '0013.png', '0052.png']
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/validation folder/img
# Directories: []
# Files: ['0050.png', '0006.png', '0003.png', '0013.png', '0052.png']
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/train folder
# Directories: ['labelcol', 'img']
# Files: []
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/train folder/labelcol
# Directories: []
# Files: ['0115.png', '0050.png', '0501.png', '0263.png', '0133.png']
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/train folder/img
# Directories: []
# Files: ['0115.png', '0050.png', '0501.png', '0263.png', '0133.png']
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/test folder
# Directories: ['img']
# Files: []
# --------------------------------------------------
# Root: /kaggle/input/bowl-2018/Bowl 2018/test folder/img
# Directories: []
# Files: ['0050.png', '0006.png', '0003.png', '0013.png', '0052.png']
# --------------------------------------------------

# %%
from skimage.io import imread
from skimage.transform import resize

# Define paths
train_img_path = "/kaggle/input/bowl-2018/Bowl 2018/train folder/img"
train_mask_path = "/kaggle/input/bowl-2018/Bowl 2018/train folder/labelcol"

# Define image dimensions
IMG_HEIGHT, IMG_WIDTH = 128, 128  # Resized dimensions
IMG_CHANNELS = 3  # RGB

# Load and preprocess training images
def load_data(img_path, mask_path, img_height, img_width):
    images = []
    masks = []
    for file_name in os.listdir(img_path):
        # Load and normalize image
        img = imread(os.path.join(img_path, file_name))
        img = resize(img, (img_height, img_width, IMG_CHANNELS), mode='constant', preserve_range=True)
        img = img / 255.0  # Normalize to [0, 1]
        images.append(img)

        # Load and normalize corresponding mask
        mask = imread(os.path.join(mask_path, file_name), as_gray=True)
        mask = resize(mask, (img_height, img_width, 1), mode='constant', preserve_range=True)
        mask = mask / 255.0  # Normalize to [0, 1]
        masks.append(mask)

    return np.array(images), np.array(masks)

# Load training data
train_images, train_masks = load_data(train_img_path, train_mask_path, IMG_HEIGHT, IMG_WIDTH)

# Print shapes for confirmation
print("Train Images Shape:", train_images.shape)
print("Train Masks Shape:", train_masks.shape)
# Out:
# Train Images Shape: (520, 128, 128, 3)
# Train Masks Shape: (520, 128, 128, 1)

# %%
def unet_model(input_size=(128, 128, 3)):
    inputs = Input(input_size)
    
    # Encoder (downsampling)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    
    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    
    # Decoder (upsampling)
    u1 = UpSampling2D((2, 2))(c4)
    u1 = concatenate([u1, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u1)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)
    
    u2 = UpSampling2D((2, 2))(c5)
    u2 = concatenate([u2, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)
    
    u3 = UpSampling2D((2, 2))(c6)
    u3 = concatenate([u3, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u3)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)
    
    # Output layer
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Build the model
model = unet_model()
model.summary()
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_90[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 64, 64,    │          0 │ conv2d_91[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_18… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_92[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 32, 32,    │          0 │ conv2d_93[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_19… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_94[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 16, 16,    │          0 │ conv2d_95[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_20… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ conv2d_96[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 32, 32,    │          0 │ conv2d_97[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 32, 32,    │          0 │ up_sampling2d_18… │
# │ (Concatenate)       │ 768)              │            │ conv2d_95[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ concatenate_18[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_98[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 64, 64,    │          0 │ conv2d_99[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 64, 64,    │          0 │ up_sampling2d_19… │
# │ (Concatenate)       │ 384)              │            │ conv2d_93[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 64, 64,    │    442,496 │ concatenate_19[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 64, 64,    │    147,584 │ conv2d_100[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_20    │ (None, 128, 128,  │          0 │ conv2d_101[0][0]  │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 128, 128,  │          0 │ up_sampling2d_20… │
# │ (Concatenate)       │ 192)              │            │ conv2d_91[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 128, 128,  │    110,656 │ concatenate_20[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 128, 128,  │     36,928 │ conv2d_102[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 128, 128,  │         65 │ conv2d_103[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,782,913 (29.69 MB)
#  Trainable params: 7,782,913 (29.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Split a small part of training data for validation
from sklearn.model_selection import train_test_split

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_images, train_masks, test_size=0.2, random_state=42)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=16,
    epochs=30,
    verbose=1
)
# Generate raw predictions and check their range
raw_preds = model.predict(X_val)
print("Raw prediction range:", raw_preds.min(), raw_preds.max())
# Out:
# Epoch 1/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.6271 - loss: 0.6461 - val_accuracy: 0.7873 - val_loss: 0.4601
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8076 - loss: 0.4150 - val_accuracy: 0.7873 - val_loss: 0.4004
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7869 - loss: 0.4062 - val_accuracy: 0.7873 - val_loss: 0.3198
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.8107 - loss: 0.2809 - val_accuracy: 0.7873 - val_loss: 0.2469
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.8083 - loss: 0.2260 - val_accuracy: 0.7845 - val_loss: 0.2240
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8058 - loss: 0.1987 - val_accuracy: 0.8168 - val_loss: 0.1781
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8369 - loss: 0.1542 - val_accuracy: 0.8100 - val_loss: 0.1728
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8167 - loss: 0.1752 - val_accuracy: 0.8181 - val_loss: 0.1493
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8409 - loss: 0.1303 - val_accuracy: 0.8203 - val_loss: 0.1349
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8343 - loss: 0.1184 - val_accuracy: 0.8258 - val_loss: 0.1198
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8345 - loss: 0.1201 - val_accuracy: 0.8269 - val_loss: 0.1218
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8361 - loss: 0.1151 - val_accuracy: 0.8255 - val_loss: 0.1159
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8417 - loss: 0.1019 - val_accuracy: 0.8268 - val_loss: 0.1073
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8297 - loss: 0.1068 - val_accuracy: 0.8271 - val_loss: 0.1092
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8400 - loss: 0.0994 - val_accuracy: 0.8280 - val_loss: 0.1051
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.8352 - loss: 0.0991 - val_accuracy: 0.8276 - val_loss: 0.1026
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8422 - loss: 0.1000 - val_accuracy: 0.8280 - val_loss: 0.1044
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.8390 - loss: 0.1009 - val_accuracy: 0.8273 - val_loss: 0.0984
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8448 - loss: 0.0909 - val_accuracy: 0.8281 - val_loss: 0.1085
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8528 - loss: 0.0862 - val_accuracy: 0.8274 - val_loss: 0.0965
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8457 - loss: 0.0875 - val_accuracy: 0.8277 - val_loss: 0.0937
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8567 - loss: 0.0781 - val_accuracy: 0.8274 - val_loss: 0.0931
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - accuracy: 0.8375 - loss: 0.0872 - val_accuracy: 0.8276 - val_loss: 0.0913
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8426 - loss: 0.0826 - val_accuracy: 0.8276 - val_loss: 0.0903
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8408 - loss: 0.0833 - val_accuracy: 0.8258 - val_loss: 0.0961
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.8400 - loss: 0.0863 - val_accuracy: 0.8277 - val_loss: 0.0918
# Epoch 27/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8421 - loss: 0.0820 - val_accuracy: 0.8276 - val_loss: 0.0910
# Epoch 28/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.8421 - loss: 0.0797 - val_accuracy: 0.8274 - val_loss: 0.0921
# Epoch 29/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8458 - loss: 0.0790 - val_accuracy: 0.8279 - val_loss: 0.0954
# Epoch 30/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8496 - loss: 0.0774 - val_accuracy: 0.8280 - val_loss: 0.0890
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step
# Raw prediction range: 1.396808e-09 0.9984933

# %%
# Visualize a few samples
import random

# Threshold predictions at 0.5 to create binary masks
preds_binary = (raw_preds > 0.5).astype(np.uint8)

# Randomly select 5 samples
random_idx = random.sample(range(len(X_val)), 5)

plt.figure(figsize=(15, 10))
for i, idx in enumerate(random_idx):
    # Input Image
    plt.subplot(3, 5, i + 1)
    plt.imshow(X_val[idx])
    plt.title("Input Image")
    plt.axis('off')
    
    # Ground Truth Mask
    plt.subplot(3, 5, i + 6)
    plt.imshow(y_val[idx].squeeze(), cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis('off')
    
    # Predicted Mask
    plt.subplot(3, 5, i + 11)
    plt.imshow(preds_binary[idx].squeeze(), cmap='gray')
    plt.title("Predicted Mask")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import jaccard_score

def dice_coefficient(y_true, y_pred):
    """Calculate the Dice Coefficient."""
    smooth = 1.0  # Avoid division by zero
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def evaluate_performance(y_true, y_pred):
    """Evaluate Dice and IoU metrics."""
    dice = dice_coefficient(y_true, y_pred)
    iou = jaccard_score(y_true.flatten(), y_pred.flatten(), average='binary')
    accuracy = np.mean(y_true == y_pred)
    return dice, iou, accuracy

# Ensure y_val is binary
y_val_binary = (y_val > 0.5).astype(np.uint8)  # Threshold ground truth masks to binary

# Evaluate on validation set
dice, iou, accuracy = evaluate_performance(y_val_binary, preds_binary)

print(f"Dice Coefficient: {dice:.4f}")
print(f"IoU (Jaccard Index): {iou:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Dice Coefficient: 0.8984
# IoU (Jaccard Index): 0.8155
# Accuracy: 0.9717

# %%
model.save("unet_model.h5")
